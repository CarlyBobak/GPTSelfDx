# %%
import pandas as pd
import numpy as np
import torch

from transformers import AutoTokenizer, AutoModel
from sklearn.decomposition import PCA

import umap
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/yiwei/Documents/Work & Research/ITC-RC/WebMD/nlp/lib/python3.9/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/yiwei/Documents/Work & Research/ITC-RC/WebMD/nlp/lib/python3.9/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/yiwei/Documents/Work & Research/ITC-RC/WebMD/nlp/lib/python3.9/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/yiwei/Documents/Work & Research/ITC-RC/WebMD/nlp/lib/python3.9/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
sns.set(rc={'figure.dpi':120, 'figure.figsize':(10,8)})

# %% [markdown]
# References:
#
# 1. BERT structure: https://medium.com/@dhartidhami/understanding-bert-word-embeddings-7dc4d2ea54ca
#
# 2. Bio_ClinicalBERT paper: https://arxiv.org/pdf/1904.03323.pdf
#
# 3. tSNE vs. UMAP: https://towardsdatascience.com/tsne-vs-umap-global-structure-4d8045acba17

# %%
data = pd.read_csv("Data/subset.csv", index_col = 0)
data.head()
# Out:
#    Patient ID  Age     Sex    Official_DX Rater_DX_Clean  \
# 0           1   35  Female           Cold      Allergies
# 1           2   20    Male      Allergies      Allergies
# 2           3   31    Male     Depression     Depression
# 3           4   61    Male  Heart Disease  Heart Failure
# 4           5   34  Female     Depression     Depression
#
#             ChatGPT_Clean_1           ChatGPT_Clean_2  \
# 0                 Allergies                 Allergies
# 1                 Allergies                 Allergies
# 2                Depression                Depression
# 3  Congestive Heart Failure  Congestive Heart Failure
# 4                Depression                Depression
#
#             ChatGPT_Clean_3
# 0                 Allergies
# 1                 Allergies
# 2                Depression
# 3  Congestive Heart Failure
# 4                Depression

# %% [markdown]
# ### Cleaning

# %%
Official_DX = data.Official_DX.tolist()
Rater_DX_Clean = data.Rater_DX_Clean.tolist()
ChatGPT_Clean_1 = data.ChatGPT_Clean_1.tolist()
ChatGPT_Clean_2 = data.ChatGPT_Clean_2.tolist()
ChatGPT_Clean_3 = data.ChatGPT_Clean_3.tolist()

# make to lowercase
Official_DX = [x.lower() for x in Official_DX]
Rater_DX_Clean = [x.lower() for x in Rater_DX_Clean]
ChatGPT_Clean_1 = [x.lower() for x in ChatGPT_Clean_1]
ChatGPT_Clean_2 = [x.lower() for x in ChatGPT_Clean_2]
ChatGPT_Clean_3 = [x.lower() for x in ChatGPT_Clean_3]

# add back to df
data.loc[:, 'Official_DX'] = Official_DX
data.loc[:, 'Rater_DX_Clean'] = Rater_DX_Clean
data.loc[:, 'ChatGPT_Clean_1'] = ChatGPT_Clean_1
data.loc[:, 'ChatGPT_Clean_2'] = ChatGPT_Clean_2
data.loc[:, 'ChatGPT_Clean_3'] = ChatGPT_Clean_3

data.head()
# Out:
#    Patient ID  Age     Sex    Official_DX Rater_DX_Clean  \
# 0           1   35  Female           cold      allergies
# 1           2   20    Male      allergies      allergies
# 2           3   31    Male     depression     depression
# 3           4   61    Male  heart disease  heart failure
# 4           5   34  Female     depression     depression
#
#             ChatGPT_Clean_1           ChatGPT_Clean_2  \
# 0                 allergies                 allergies
# 1                 allergies                 allergies
# 2                depression                depression
# 3  congestive heart failure  congestive heart failure
# 4                depression                depression
#
#             ChatGPT_Clean_3
# 0                 allergies
# 1                 allergies
# 2                depression
# 3  congestive heart failure
# 4                depression

# %% [markdown]
# ### Word Embedding

# %%
tokenizer = AutoTokenizer.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
model = AutoModel.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")

# %%
# get unique diagnosis from all columns
allList = []

allList.extend(Official_DX)
allList.extend(Rater_DX_Clean)
allList.extend(ChatGPT_Clean_1)
allList.extend(ChatGPT_Clean_2)
allList.extend(ChatGPT_Clean_3)

unique_list = list(set(allList))

# %%
# create a df
vector = pd.DataFrame(unique_list, columns = ['Diagnosis'])
vector
# Out:
#                    Diagnosis
# 0              heart disease
# 1   congestive heart failure
# 2            prostate issues
# 3                     asthma
# 4                  epistaxis
# 5                     anemia
# 6           cluster headache
# 7                 arrhythmia
# 8              breast cancer
# 9               hypoglycemia
# 10           pulmonary edema
# 11               myocarditis
# 12          anxiety disorder
# 13                       flu
# 14                       ibd
# 15          high blood sugar
# 16                depression
# 17                 menopause
# 18                 arthritis
# 19           gastroenteritis
# 20              hypertension
# 21              appendicitis
# 22                 allergies
# 23             heart failure
# 24      neuroendocrine tumor
# 25                      cold
# 26         polycythemia vera
# 27                  diabetes
# 28                  migraine
# 29              fibromyalgia
# 30               common cold
# 31           prostate cancer

# %%
# create a function to generate vectors
def getVec(word):
    
    # Tokenize the text and convert to IDs
    tokens = tokenizer(word, return_tensors="pt")
    input_ids = tokens["input_ids"]
    attention_mask = tokens["attention_mask"]

    # Pass the input through the model to get embeddings
    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)

    # Extract embeddings from the output
    word_embeddings = outputs.last_hidden_state

    # Get the embedding for the first token (CLS token) representing the entire sentence
    # this step is useful when the input is a sentence
    word_embeddings = word_embeddings[:, 0, :]

    # Convert to a numpy array
    word_embeddings = word_embeddings.numpy()

    return word_embeddings[0]

# %%
vec = vector.Diagnosis.apply(lambda x: getVec(x))

vecs = pd.DataFrame(vec.tolist())

# %% [markdown]
# ### PCA

# %%
pca = PCA(n_components=2)
unique_pca = pd.DataFrame(pca.fit_transform(vecs))

# %%
vectors_pca = pd.concat([vector, unique_pca], axis=1)
vectors_pca.columns = ["Official_DX", "PC1", "PC2"]
vectors_pca
# Out:
#                  Official_DX       PC1       PC2
# 0              heart disease -0.790029 -2.599319
# 1   congestive heart failure -1.550110 -2.174083
# 2            prostate issues -0.298624  0.920636
# 3                     asthma -1.605635  0.445932
# 4                  epistaxis  1.244438 -0.419498
# 5                     anemia -0.590427  1.329146
# 6           cluster headache -0.034033  1.197486
# 7                 arrhythmia  1.641334 -1.378182
# 8              breast cancer -2.714422 -0.768046
# 9               hypoglycemia  2.074995 -1.417682
# 10           pulmonary edema  2.184886  0.168324
# 11               myocarditis -1.404377 -0.171084
# 12          anxiety disorder -1.692536  1.259822
# 13                       flu  0.978801  3.741585
# 14                       ibd  3.759498  1.398493
# 15          high blood sugar  3.774730 -1.983059
# 16                depression -1.419523  1.785438
# 17                 menopause -2.428198  1.516632
# 18                 arthritis -2.111703  0.169038
# 19           gastroenteritis -0.364353 -1.325034
# 20              hypertension -1.324172 -0.282494
# 21              appendicitis  0.402707 -1.552628
# 22                 allergies  3.103520 -2.371565
# 23             heart failure  0.068972 -2.637156
# 24      neuroendocrine tumor  0.344157 -2.040071
# 25                      cold  4.022209  2.985603
# 26         polycythemia vera -1.788278  0.465538
# 27                  diabetes -0.556895  2.574706
# 28                  migraine -1.446073  1.061586
# 29              fibromyalgia -2.125790 -0.154950
# 30               common cold  2.968403  1.278566
# 31           prostate cancer -2.323468 -1.023680

# %%
#vectors_pca.to_csv("Data/vectors_pca.csv")

# %% [markdown]
# ### UMAP

# %%
reducer = umap.UMAP(n_components=2)
embedding = pd.DataFrame(reducer.fit_transform(vecs).tolist())

# %%
vectors_umap = pd.concat([vector, embedding], axis=1)
vectors_umap.columns = ["Official_DX", "D1", "D2"]
vectors_umap
# Out:
#                  Official_DX        D1        D2
# 0              heart disease -4.776361  6.927000
# 1   congestive heart failure -4.723830  7.444934
# 2            prostate issues -5.675931  7.211980
# 3                     asthma -6.011960  8.436414
# 4                  epistaxis -6.077126  5.505810
# 5                     anemia -7.058075  7.254637
# 6           cluster headache -6.708802  6.711996
# 7                 arrhythmia -5.489654  5.228036
# 8              breast cancer -4.890868  8.036383
# 9               hypoglycemia -5.257232  5.403402
# 10           pulmonary edema -5.288633  5.990703
# 11               myocarditis -6.578371  9.008856
# 12          anxiety disorder -6.632112  7.564673
# 13                       flu -6.797605  8.616744
# 14                       ibd -5.942282  6.402575
# 15          high blood sugar -5.020279  5.496853
# 16                depression -6.794747  8.045801
# 17                 menopause -6.077020  7.417525
# 18                 arthritis -6.075295  7.970472
# 19           gastroenteritis -5.607373  6.477914
# 20              hypertension -5.432912  7.768588
# 21              appendicitis -5.820266  5.896987
# 22                 allergies -6.380887  5.851718
# 23             heart failure -4.549069  6.642099
# 24      neuroendocrine tumor -5.177532  6.560401
# 25                      cold -6.248640  4.824687
# 26         polycythemia vera -5.886100  9.024991
# 27                  diabetes -7.311795  7.803097
# 28                  migraine -6.425662  7.102425
# 29              fibromyalgia -5.367177  8.386294
# 30               common cold -6.555748  5.124980
# 31           prostate cancer -4.560118  7.811555

# %%
#vectors_umap.to_csv("Data/vectors_umap.csv")
